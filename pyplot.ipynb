# %% [markdown]
# # Fundamentals of Data Analysis Assignment
# ## Autumn 2021
#
# ---
# <br>
#
# ## Part 1 - matplotlib.pyplot
# ---

# %% [markdown]
# ![matplotlibLogo](./Images/Matplotlib2.png)

# %% [markdown]
# >'Matplotlib is the bread and butter of data visualization in Python.'

# %% [markdown]
# Matplotlib is a plotting library for creating visualizations in Python. Pyplot is a module within matplotlib that contains a multitude of functions for the creation and manipulation of figures and plots.

# %% [markdown]
# #### Ex. 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# I found a few wine datasets online, and as I'm quite fond of the stuff, I'm going to use those for the plots!

# %%
df = pd.read_excel('data/Wine_data.xlsx')  
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# histogram of 'quality' scores
data=df['quality']
fig, axs = plt.subplots(1, 1, figsize =(10, 7),tight_layout = True)
axs.grid(b = True, color ='grey', linestyle ='-.', linewidth = 0.5, alpha = 0.6)
plt.xlabel("Quality Score")
plt.ylabel("Frequency")
plt.hist(data, color="r", edgecolor ="black")
# Out:
# (array([  20.,  163.,    0., 1457.,    0., 2198.,  880.,    0.,  175.,
#            5.]),
#  array([3. , 3.6, 4.2, 4.8, 5.4, 6. , 6.6, 7.2, 7.8, 8.4, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
# histogram of 'quality' scores
data=df['sulphates']
fig, axs = plt.subplots(1, 1, figsize =(10, 7),tight_layout = True)
axs.grid(b = True, color ='grey', linestyle ='-.', linewidth = 0.5, alpha = 0.6)
plt.xlabel("sulphates")
plt.ylabel("Frequency")
plt.hist(data, color="blue", edgecolor ="black")
# Out:
# (array([  83.,  931., 1440., 1402.,  595.,  263.,  134.,   26.,   20.,
#            4.]),
#  array([0.22 , 0.306, 0.392, 0.478, 0.564, 0.65 , 0.736, 0.822, 0.908,
#         0.994, 1.08 ]),
#  <BarContainer object of 10 artists>)

# %%
# comaparing alcohol with quality score
# https://www.geeksforgeeks.org/matplotlib-pyplot-scatter-in-python/
x = df['quality']
y = df['alcohol']
plt.xlabel('quality_score')
plt.ylabel('alcohol_%')
plt.rcParams["figure.figsize"] = (13,8)
# bit of formatting - explain?
plt.scatter(x,y, c="r", linewidths = 1, marker ="^", edgecolor ="green", s = 30)

# %%
# attempt at a 4d scatter!
# x axis = alcohol
# y axis = pH
# colour = quality score
# size = residual sugar

# https://www.w3schools.com/python/matplotlib_markers.asp
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

data = {'a': df['alcohol'],
        'b': df['pH'],
        'c': df['quality'],
        'd': df['residual sugar']}
plt.scatter('a', 'b', c='c', s='d', data=data, marker = '*')
plt.xlabel('alcohol_%')
plt.ylabel('pH')
plt.rcParams["figure.figsize"] = (13,8)
plt.rcParams['image.cmap']='jet'
# jet seems to convey the data best!
plt.grid(color = 'green', linestyle = '--', linewidth = 0.2, alpha = 0.5)
plt.show()

# %%
# Ex. 1
# Create a figure and an axes with pyplot.subplots()
fig,axs = plt.subplots(figsize=(15,7))

data1 = df['sulphates']
data2 = df['volatile acidity']
data3 = df['citric acid']

# plots the data of each variable
# specifies the 'marker' for each
axs.plot(data1,marker="o", label='sulphates', alpha=0.2)
axs.plot(data2,marker="*", label='volatile acidity', alpha=0.2)
axs.plot(data3,marker="^", label='citric acid', alpha=0.2)
# x and y labels

axs.set_xlabel("Frequency")
axs.set_ylabel("Amount")
# creates an overall table
axs.set_title("Wine - sulpahtes vs volatile acidity vs citric acid")
# creates a background grid
axs.grid("on")
# creates a legend
plt.legend()
# defines the colour scheme
plt.rcParams['image.cmap']='jet'
# creates the plot
plt.show()

# %% [markdown]
# Gonna try some of the above with a different wine dataset!

# %%
# Load the wine data set from a URL.
df_wine2 = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data", header=None)
df_wine2.columns = ['name','alcohol','malicAcid','ash','ashalcalinity','magnesium','totalPhenols','flavanoids'
              ,'nonFlavanoidPhenols','proanthocyanins','colorIntensity','hue','od280_od315','proline']
df_wine2
# Out:
#      name  alcohol  malicAcid   ash  ashalcalinity  magnesium  totalPhenols  \
# 0       1    14.23       1.71  2.43           15.6        127          2.80
# 1       1    13.20       1.78  2.14           11.2        100          2.65
# 2       1    13.16       2.36  2.67           18.6        101          2.80
# 3       1    14.37       1.95  2.50           16.8        113          3.85
# 4       1    13.24       2.59  2.87           21.0        118          2.80
# ..    ...      ...        ...   ...            ...        ...           ...
# 173     3    13.71       5.65  2.45           20.5         95          1.68
# 174     3    13.40       3.91  2.48           23.0        102          1.80
# 175     3    13.27       4.28  2.26           20.0        120          1.59
# 176     3    13.17       2.59  2.37           20.0        120          1.65
# 177     3    14.13       4.10  2.74           24.5         96          2.05
#
# ...

# %%
data = {'a': df_wine2['alcohol'],
        'b': df_wine2['malicAcid'],
        'c': df_wine2['colorIntensity'],
        'd': df_wine2['name']}
plt.scatter('a', 'b', c='c', s='d', data=data, marker = '*')
plt.xlabel('alcohol_%')
plt.ylabel('malicAcid')
# plt.rcParams["figure.figsize"] = (13,8)
# plt.rcParams['image.cmap']='jet'
# jet seems to convey the data best!
plt.grid(color = 'green', linestyle = '--', linewidth = 0.2, alpha = 0.5)
plt.show()

# %%
# Ex. 1
# Create a figure and an axes with pyplot.subplots()
fig,axs = plt.subplots(figsize=(15,7))

data1 = df_wine2['totalPhenols']
data2 = df_wine2['flavanoids']
data3 = df_wine2['nonFlavanoidPhenols']
data4 = df_wine2['proanthocyanins']

# plots the data of each variable
# specifies the 'marker' for each
axs.plot(data1,marker="o", label='totalPhenols', alpha=0.2)
axs.plot(data2,marker="*", label='flavanoids', alpha=0.2)
axs.plot(data3,marker="^", label='nonFlavanoidPhenols', alpha=0.2)
axs.plot(data4,marker="x", label='proanthocyanins', alpha=0.2)
# x and y labels

axs.set_xlabel("Frequency")
axs.set_ylabel("Amount")
# creates an overall table
axs.set_title("Wine - totalPhenols vs flavenoids vs nonFlavanoidPhenols vs proanthocyanins")
# creates a background grid
axs.grid("on")
# creates a legend
plt.legend()
# defines the colour scheme
# plt.rcParams['image.cmap']='jet'
# creates the plot
plt.show()

# %% [markdown]
# ## Plots

# %% [markdown]
# Examples from: https://towardsdatascience.com/a-practical-summary-of-matplotlib-in-13-python-snippets-4d07f0011bdf

# %% [markdown]
# #### Ex. 2

# %%
# Create the data
x = np.cos(np.linspace(0, 2, 100))
# Create a figure and an axes with pyplot.subplots()
fig, ax = plt.subplots()  
# Plot some data on the axes
ax.plot(x, x, label='linear')  
ax.plot(x, x**2, label='quadratic')
ax.plot(x, x**3, label='cubic')
# add x and y lables
ax.set_xlabel('x label')
ax.set_ylabel('y label')
# Add a title to the axes
ax.set_title("Simple Plot")  
# Add a legend
ax.legend();  
plt.show()

# %% [markdown]
# #### Ex. 3

# %%
# different way of doing the same
x = np.cos(np.linspace(0, 2, 100))
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()
plt.show()

# %% [markdown]
# #### Ex. 4

# %%
# experimenting with formatting
t = np.sin(np.linspace(-3,3,50))
# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', color="red")
plt.plot(t, t**2, 'bs', color="blue")
plt.plot(t, t**3, 'g^', color="green")
plt.plot(t, t**4, "o", color="orange")
plt.plot(t, t**5, "o-", color="black")
plt.show()

# %% [markdown]
# #### Ex. 5

# %%
# source: https://matplotlib.org/stable/gallery/misc/keyword_plotting.html

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# #### Ex. 6

# %%
names = ['cats', 'dogs', 'dragons']
values = [5, 25, 125]
plt.figure(figsize=(15, 7))
plt.subplot(131)
plt.bar(names, values, color="red", label="bar chart")
plt.legend()
plt.subplot(132)
plt.scatter(names, values, color="orange", label="scatter plot")
plt.legend()
plt.subplot(133)
plt.plot(names, values, color="green", label="line plot")
plt.legend()
plt.suptitle('Categorical Plots')
plt.show()

# %% [markdown]
# #### Ex. 7

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.2)

plt.figure()

plt.subplot(2,2,1)
plt.plot(t1, f(t1), 'black')

plt.subplot(2,2,2)
plt.plot(t2, np.tan(2*np.pi*t2), 'r--')

plt.subplot(2,2,3)
plt.plot(t2, np.exp(t2), 'g^')

plt.subplot(2,2,4)
plt.plot(t2, np.cos(2*np.pi*t2), 'orange');
plt.show()

# %% [markdown]
# #### Ex. 8

# %%
#source: https://matplotlib.org/stable/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# #### Ex. 9

# %%
# adapted from: https://matplotlib.org/stable/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py

# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y, color="red")
plt.yscale('linear')
plt.title('linear',color="red")
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y, color="green")
plt.yscale('log')
plt.title('log',color="green")
plt.grid(True)

# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean(),color="blue")
plt.yscale('symlog', linthresh=0.01)
plt.title('symlog',color="blue")
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y, color="orange")
plt.yscale('logit')
plt.title('logit',color="orange")
plt.grid(True)
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ex. 10

# %%
ax = plt.subplot()

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# # END
